# %% [markdown]
# ##Use catalog Workspace

# %%
# %sql
USE CATALOG workspace ;

# %% [markdown]
# ##Create Schemas

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze 
COMMENT 'BRONZE Layer : raw data' ;
CREATE SCHEMA IF NOT EXISTS silver 
COMMENT 'SILVER Layer : cleaned,transformed data' ;
CREATE SCHEMA IF NOT EXISTS gold 
COMMENT 'GOLD Layer : business-ready data' ;

# %% [markdown]
# ##Create volume

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.bronze.raw_sources  
COMMENT 'Volume For Raw data (csv files)' ;
