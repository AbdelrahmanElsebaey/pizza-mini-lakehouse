# %%
notebooks = [
    "./silver_order_details",
    "./silver_orders",
    "./silver_pizza_types",
    "./silver_pizzas"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
