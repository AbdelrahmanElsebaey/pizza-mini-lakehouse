# %%
print('running pipeline...')
dbutils.notebook.run('init_lakehouse',timeout_seconds=0)
dbutils.notebook.run('bronze/bronze',timeout_seconds=0)
dbutils.notebook.run('silver/silver_orchestration',timeout_seconds=0)
dbutils.notebook.run('gold/gold_orchestration',timeout_seconds=0)
print('pipeline completed successfully!')
